# %%
import pandas as pd, numpy as np

# %%
data = pd.read_csv("clint.csv").drop("Unnamed: 0", 1)
data
# Out:
#          color     command deleted               from  \
# 0      #2612BA         NaN   False           jtsnow77
# 1      #008000         NaN   False      posionpancake
# 2      #DAA520         NaN   False      thirteenjhm13
# 3      #8A2BE2         NaN   False        greedisgo0d
# 4          NaN         NaN   False              wondl
# 5      #CD9FFE         NaN   False       springysheep
# 6      #1E90FF         NaN   False          alphador_
# 7      #E6C300         NaN   False      chuckthegypsy
# 8      #FF0000         NaN   False  not_a_speedrunner
# 9      #725E4B         NaN   False            laboonm
# 10     #7A00CC         NaN   False        scuffedruns
# 11     #5F9EA0         NaN   False           shirazrl
# 12         NaN         NaN   False    madolcheanjelly
# 13     #0000FF         NaN   False       thanatoast01
# 14     #E6C300         NaN   False      chuckthegypsy
# 15     #FF7B00         NaN   False            chiz001
# 16     #008000         NaN   False          glaukopes
# 17         NaN         NaN   False           quikheet
# 18     #666666         NaN   False            dima110
# 19     #2612BA         NaN   False           jtsnow77
# 20     #00CCC5         NaN   False    recklessrelapse
# 21     #1E90FF         NaN   False         ninjabacca
# 22     #DA70D6  USERNOTICE   False          tuffy4255
# 23     #00CC2C         NaN   False           quacrunk
# 24         NaN         NaN   False           quikheet
# 25     #DAA520         NaN   False      thirteenjhm13
# 26     #8A2BE2         NaN   False            fluxayy
# 27     #00CCC5         NaN   False    recklessrelapse
# 28     #1DAFA3         NaN   False           iansynth
# 29     #FF69B4         NaN   False           avian141
# ...        ...         ...     ...                ...
# 12523  #00FF7F         NaN   False       dustin_clark
# 12524  #F497DE         NaN   False            bambiku
# 12525  #0000FF         NaN   False          khriz0571
# 12526      NaN         NaN   False        ryanjosephv
# 12527  #5F9EA0         NaN   False           argoncat
# 12528  #5F9EA0         NaN   False           argoncat
# 12529  #CD9FFE         NaN   False             xenoda
# 12530  #8D082A         NaN   False       pure__pazaak
# 12531  #1E90FF         NaN   False           immabard
# 12532  #9ACD32         NaN   False      creepincancer
# 12533  #8D082A         NaN   False       pure__pazaak
# 12534      NaN         NaN   False          howlucky4
# 12535  #1E90FF         NaN   False           immabard
# 12536      NaN         NaN   False          lederamar
# 12537      NaN         NaN   False  jared_jared_jared
# 12538  #FF0000         NaN   False        hurpyhooves
# 12539  #0000FF         NaN   False         ra1n_mak3r
# 12540      NaN         NaN   False          lederamar
# 12541  #FF69B4         NaN   False             moobot
# 12542  #00CCC9         NaN   False      superenergiez
# 12543  #FF69B4         NaN   False    zerotheabsolute
# 12544  #008000         NaN   False      20kills1night
# 12545      NaN         NaN   False         clamstrong
# 12546  #CC004B         NaN   False      bradpittshair
# 12547  #00CCC9         NaN   False      superenergiez
# 12548  #1E90FF         NaN   False           immabard
# 12549  #8A2BE2         NaN   False          rawfulma0
# 12550  #00CCC9         NaN   False      superenergiez
# 12551      NaN         NaN   False         clamstrong
# 12552  #00C9CC         NaN   False         dadnuggets
#
#                                                  message          room  \
# 0                                               PogChamp  clintstevens
# 1                                               PogChamp  clintstevens
# 2                                               PogChamp  clintstevens
# 3                                                HeyGuys  clintstevens
# 4                                                 WOOOOO  clintstevens
# 5                                               HI CLINT  clintstevens
# 6                                               PogChamp  clintstevens
# 7                                               hi clint  clintstevens
# 8                                                    yee  clintstevens
# 9                                              hes alive  clintstevens
# 10                            PogChamp WE IN IT PogChamp  clintstevens
# 11                                              PogChamp  clintstevens
# 12                                                   dad  clintstevens
# 13                                             hey clint  clintstevens
# 14                     @ClintStevens, hey wanna play OW?  clintstevens
# 15                               Clinty-winty-woo danAww  clintstevens
# 16                                               Kappa /  clintstevens
# 17                                         woooooooooooo  clintstevens
# 18                          is psn down for anyone else?  clintstevens
# 19                             hey @ClintStevens clintYo  clintstevens
# 20                                              PogChamp  clintstevens
# 21                                    hows i going clint  clintstevens
# 22                                              PogChamp           NaN
# 23                               heyyyyyyyyyyyyyyyyyyyyy  clintstevens
# 24                                                   DAD  clintstevens
# 25                                happy easter clintoris  clintstevens
# 26                                Clintu!! @Clintstevens  clintstevens
# 27                                    hey Clint TehePelo  clintstevens
# 28                                              HI CLINT  clintstevens
# 29                                              PogChamp  clintstevens
# ...                                                  ...           ...
# 12523                                            TriHard  clintstevens
# 12524                                       ori moon2WOW  clintstevens
# 12525                        really? i'll buy it then :D  clintstevens
# 12526                              I miss the real Clint  clintstevens
# 12527                                     you get emotes  clintstevens
# 12528                                                LUL  clintstevens
# 12529                            i love ori FeelsGoodMan  clintstevens
# 12530                                       FeelsGoodMan  clintstevens
# 12531                                       FeelsGoodMan  clintstevens
# 12532  Yeah @khriz0571 it is worth the money. It also...  clintstevens
# 12533                                        KonCha bard  clintstevens
# 12534                                      What happened  clintstevens
# 12535                                     pure OSsloth /  clintstevens
# 12536                                            !poinyd  clintstevens
# 12537                      How is everyone's night going  clintstevens
# 12538                                             clintB  clintstevens
# 12539                  its a conceptually beautiful game  clintstevens
# 12540                                            !points  clintstevens
# 12541  You have exactly 51 Clintpoints! Spam more in ...  clintstevens
# 12542                                         hello bard  clintstevens
# 12543                                     Clint is done?  clintstevens
# 12544                           Oh damn, did Clint quit?  clintstevens
# 12545                                      he just left?  clintstevens
# 12546  @hayleydanger that's cool to be able to say. S...  clintstevens
# 12547                                             superT  clintstevens
# 12548                                             enerGZ  clintstevens
# 12549                          now what do i do BabyRage  clintstevens
# 12550                                           enerGZ 7  clintstevens
# 12551  guys we have to make him happier as his twitch...  clintstevens
# 12552                                    Where did he go  clintstevens
#
#            timestamp  video-offset                              badges  bits  \
# 0      1492400397504           504               subscriber/12,turbo/1   NaN
# 1      1492400397903           903                                 NaN   NaN
# 2      1492400397909           909                        subscriber/3   NaN
# 3      1492400400077          3077                                 NaN   NaN
# 4      1492400400204          3204                            bits/100   NaN
# 5      1492400400918          3918                           bits/1000   NaN
# 6      1492400401903          4903                           premium/1   NaN
# 7      1492400402355          5355             subscriber/12,premium/1   NaN
# 8      1492400404154          7154                                 NaN   NaN
# 9      1492400404822          7822                        subscriber/6   NaN
# 10     1492400405202          8202              subscriber/3,bits/1000   NaN
# 11     1492400405522          8522                                 NaN   NaN
# 12     1492400405566          8566                                 NaN   NaN
# 13     1492400407217         10217                            bits/100   NaN
# 14     1492400407277         10277             subscriber/12,premium/1   NaN
# 15     1492400407703         10703                           premium/1   NaN
# 16     1492400408551         11551                                 NaN   NaN
# 17     1492400408764         11764                                 NaN   NaN
# 18     1492400409333         12333                           bits/1000   NaN
# 19     1492400409979         12979               subscriber/12,turbo/1   NaN
# 20     1492400410182         13182                            bits/100   NaN
# 21     1492400410652         13652              subscriber/3,bits/1000   NaN
# 22     1492400411357         14357               subscriber/6,bits/100   NaN
# 23     1492400411735         14735              subscriber/3,premium/1   NaN
# 24     1492400413877         16877                                 NaN   NaN
# 25     1492400414881         17881                        subscriber/3   NaN
# 26     1492400415785         18785                                 NaN   NaN
# 27     1492400416506         19506                            bits/100   NaN
# 28     1492400416678         19678              subscriber/6,bits/1000   NaN
# 29     1492400417356         20356                                 NaN   NaN
# ...              ...           ...                                 ...   ...
# 12523  1492411989083      11592083              subscriber/3,premium/1   NaN
# 12524  1492411990333      11593333              subscriber/3,bits/1000   NaN
# 12525  1492411990798      11593798                                 NaN   NaN
# 12526  1492412000700      11603700                                 NaN   NaN
# 12527  1492412000811      11603811                                 NaN   NaN
# 12528  1492412004178      11607178                                 NaN   NaN
# 12529  1492412007884      11610884  moderator/1,subscriber/12,bits/100   NaN
# 12530  1492412010796      11613796             subscriber/0,bits/10000   NaN
# 12531  1492412016262      11619262               subscriber/6,bits/100   NaN
# 12532  1492412019337      11622337              subscriber/0,premium/1   NaN
# 12533  1492412021532      11624532             subscriber/0,bits/10000   NaN
# 12534  1492412028543      11631543                                 NaN   NaN
# 12535  1492412031034      11634034               subscriber/6,bits/100   NaN
# 12536  1492412034583      11637583                                 NaN   NaN
# 12537  1492412036995      11639995              subscriber/0,premium/1   NaN
# 12538  1492412038137      11641137              subscriber/3,bits/1000   NaN
# 12539  1492412038379      11641379                                 NaN   NaN
# 12540  1492412038571      11641571                                 NaN   NaN
# 12541  1492412038643      11641643                         moderator/1   NaN
# 12542  1492412039371      11642371              subscriber/0,bits/1000   NaN
# 12543  1492412041573      11644573                                 NaN   NaN
# 12544  1492412042073      11645073                                 NaN   NaN
# 12545  1492412043746      11646746                                 NaN   NaN
# 12546  1492412044555      11647555                           premium/1   NaN
# 12547  1492412045457      11648457              subscriber/0,bits/1000   NaN
# 12548  1492412048234      11651234               subscriber/6,bits/100   NaN
# 12549  1492412050612      11653612              subscriber/0,premium/1   NaN
# 12550  1492412053563      11656563              subscriber/0,bits/1000   NaN
# 12551  1492412064410      11667410                                 NaN   NaN
# 12552  1492412065533      11668533              subscriber/3,premium/1   NaN
#
#          ...     msg-param-months   room-id       sent-ts style subscriber  \
# 0        ...                  NaN  86268118  1.492400e+12   NaN       True
# 1        ...                  NaN  86268118  1.492400e+12   NaN      False
# 2        ...                  NaN  86268118  1.492400e+12   NaN       True
# 3        ...                  NaN  86268118  1.492400e+12   NaN      False
# 4        ...                  NaN  86268118  1.492400e+12   NaN      False
# 5        ...                  NaN  86268118  1.492400e+12   NaN      False
# 6        ...                  NaN  86268118  1.492400e+12   NaN      False
# 7        ...                  NaN  86268118  1.492400e+12   NaN       True
# 8        ...                  NaN  86268118  1.492400e+12   NaN      False
# 9        ...                  NaN  86268118  1.492400e+12   NaN       True
# 10       ...                  NaN  86268118  1.492400e+12   NaN       True
# 11       ...                  NaN  86268118  1.492400e+12   NaN      False
# 12       ...                  NaN  86268118  1.492400e+12   NaN      False
# 13       ...                  NaN  86268118  1.492400e+12   NaN      False
# 14       ...                  NaN  86268118  1.492400e+12   NaN       True
# 15       ...                  NaN  86268118  1.492400e+12   NaN      False
# 16       ...                  NaN  86268118  1.492400e+12   NaN      False
# 17       ...                  NaN  86268118  1.492487e+12   NaN      False
# 18       ...                  NaN  86268118  1.492400e+12   NaN      False
# 19       ...                  NaN  86268118  1.492400e+12   NaN       True
# 20       ...                  NaN  86268118  1.492400e+12   NaN      False
# 21       ...                  NaN  86268118  1.492400e+12   NaN       True
# 22       ...                  7.0  86268118           NaN   NaN       True
# 23       ...                  NaN  86268118  1.492400e+12   NaN       True
# 24       ...                  NaN  86268118  1.492487e+12   NaN      False
# 25       ...                  NaN  86268118  1.492400e+12   NaN       True
# 26       ...                  NaN  86268118  1.492400e+12   NaN      False
# 27       ...                  NaN  86268118  1.492400e+12   NaN      False
# 28       ...                  NaN  86268118  1.492400e+12   NaN       True
# 29       ...                  NaN  86268118  1.492400e+12   NaN      False
# ...      ...                  ...       ...           ...   ...        ...
# 12523    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12524    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12525    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12526    ...                  NaN  86268118           NaN   NaN      False
# 12527    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12528    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12529    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12530    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12531    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12532    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12533    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12534    ...                  NaN  86268118           NaN   NaN      False
# 12535    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12536    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12537    ...                  NaN  86268118           NaN   NaN       True
# 12538    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12539    ...                  NaN  86268118           NaN   NaN      False
# 12540    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12541    ...                  NaN  86268118           NaN   NaN      False
# 12542    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12543    ...                  NaN  86268118           NaN   NaN      False
# 12544    ...                  NaN  86268118           NaN   NaN      False
# 12545    ...                  NaN  86268118  1.492437e+12   NaN      False
# 12546    ...                  NaN  86268118           NaN   NaN      False
# 12547    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12548    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12549    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12550    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12551    ...                  NaN  86268118  1.492437e+12   NaN      False
# 12552    ...                  NaN  86268118           NaN   NaN       True
#
#                                               system-msg    tmi-sent-ts  \
# 0                                                    NaN  1492400411953
# 1                                                    NaN  1492400412324
# 2                                                    NaN  1492400412358
# 3                                                    NaN  1492400414521
# 4                                                    NaN  1492400414643
# 5                                                    NaN  1492400415321
# 6                                                    NaN  1492400416367
# 7                                                    NaN  1492400416795
# 8                                                    NaN  1492400418611
# 9                                                    NaN  1492400419259
# 10                                                   NaN  1492400419658
# 11                                                   NaN  1492400419986
# 12                                                   NaN  1492400420003
# 13                                                   NaN  1492400421676
# 14                                                   NaN  1492400421738
# 15                                                   NaN  1492400422124
# 16                                                   NaN  1492400422956
# 17                                                   NaN  1492400423207
# 18                                                   NaN  1492400423783
# 19                                                   NaN  1492400424440
# 20                                                   NaN  1492400424601
# 21                                                   NaN  1492400425098
# 22     tuffy4255\sjust\ssubscribed\swith\sTwitch\sPri...  1492400425819
# 23                                                   NaN  1492400426175
# 24                                                   NaN  1492400428343
# 25                                                   NaN  1492400429297
# 26                                                   NaN  1492400430232
# 27                                                   NaN  1492400430968
# 28                                                   NaN  1492400431129
# 29                                                   NaN  1492400431818
# ...                                                  ...            ...
# 12523                                                NaN  1492412003509
# 12524                                                NaN  1492412004770
# 12525                                                NaN  1492412005223
# 12526                                                NaN  1492412015156
# 12527                                                NaN  1492412015253
# 12528                                                NaN  1492412018616
# 12529                                                NaN  1492412022358
# 12530                                                NaN  1492412025235
# 12531                                                NaN  1492412030719
# 12532                                                NaN  1492412033752
# 12533                                                NaN  1492412035994
# 12534                                                NaN  1492412042958
# 12535                                                NaN  1492412045479
# 12536                                                NaN  1492412048986
# 12537                                                NaN  1492412051454
# 12538                                                NaN  1492412052592
# 12539                                                NaN  1492412052824
# 12540                                                NaN  1492412053027
# 12541                                                NaN  1492412053114
# 12542                                                NaN  1492412053810
# 12543                                                NaN  1492412055977
# 12544                                                NaN  1492412056534
# 12545                                                NaN  1492412058209
# 12546                                                NaN  1492412058985
# 12547                                                NaN  1492412059905
# 12548                                                NaN  1492412062562
# 12549                                                NaN  1492412065070
# 12550                                                NaN  1492412068024
# 12551                                                NaN  1492412078870
# 12552                                                NaN  1492412079987
#
#        turbo    user-id  user-type
# 0       True  109086033        NaN
# 1      False   57027344        NaN
# 2      False   35950973        NaN
# 3      False  131137126        NaN
# 4      False  143565518        NaN
# 5      False  111283120        NaN
# 6      False  139757133        NaN
# 7      False   27862377        NaN
# 8      False   94120565        NaN
# 9      False   76465212        NaN
# 10     False   56544921        NaN
# 11     False   67468924        NaN
# 12     False   79057669        NaN
# 13     False  126732184        NaN
# 14     False   27862377        NaN
# 15     False   47529299        NaN
# 16     False  104820006        NaN
# 17     False  149667282        NaN
# 18     False   29503089        NaN
# 19      True  109086033        NaN
# 20     False   30875824        NaN
# 21     False   25439059        NaN
# 22     False   56447760        NaN
# 23     False   76030467        NaN
# 24     False  149667282        NaN
# 25     False   35950973        NaN
# 26     False   72532191        NaN
# 27     False   30875824        NaN
# 28     False    7212792        NaN
# 29     False   30672515        NaN
# ...      ...        ...        ...
# 12523  False  100258639        NaN
# 12524  False  103531410        NaN
# 12525  False   86084677        NaN
# 12526  False  103725824        NaN
# 12527  False   93756801        NaN
# 12528  False   93756801        NaN
# 12529  False   53569589        mod
# 12530  False  131847836        NaN
# 12531  False   56592212        NaN
# 12532  False   73306914        NaN
# 12533  False  131847836        NaN
# 12534  False     136040        NaN
# 12535  False   56592212        NaN
# 12536  False  150591934        NaN
# 12537  False  111719683        NaN
# 12538  False   39797784        NaN
# 12539  False   78441557        NaN
# 12540  False  150591934        NaN
# 12541  False    1564983        mod
# 12542  False   30477322        NaN
# 12543  False   46052354        NaN
# 12544  False   87890295        NaN
# 12545  False   79495391        NaN
# 12546  False  120158706        NaN
# 12547  False   30477322        NaN
# 12548  False   56592212        NaN
# 12549  False   44508113        NaN
# 12550  False   30477322        NaN
# 12551  False   79495391        NaN
# 12552  False  124583694        NaN
#
# [12553 rows x 27 columns]

# %%
stop = open("stop-word-list.txt").read().splitlines()
d = data[data.message.notnull()]
d
# Out:
#          color     command deleted               from  \
# 0      #2612BA         NaN   False           jtsnow77
# 1      #008000         NaN   False      posionpancake
# 2      #DAA520         NaN   False      thirteenjhm13
# 3      #8A2BE2         NaN   False        greedisgo0d
# 4          NaN         NaN   False              wondl
# 5      #CD9FFE         NaN   False       springysheep
# 6      #1E90FF         NaN   False          alphador_
# 7      #E6C300         NaN   False      chuckthegypsy
# 8      #FF0000         NaN   False  not_a_speedrunner
# 9      #725E4B         NaN   False            laboonm
# 10     #7A00CC         NaN   False        scuffedruns
# 11     #5F9EA0         NaN   False           shirazrl
# 12         NaN         NaN   False    madolcheanjelly
# 13     #0000FF         NaN   False       thanatoast01
# 14     #E6C300         NaN   False      chuckthegypsy
# 15     #FF7B00         NaN   False            chiz001
# 16     #008000         NaN   False          glaukopes
# 17         NaN         NaN   False           quikheet
# 18     #666666         NaN   False            dima110
# 19     #2612BA         NaN   False           jtsnow77
# 20     #00CCC5         NaN   False    recklessrelapse
# 21     #1E90FF         NaN   False         ninjabacca
# 22     #DA70D6  USERNOTICE   False          tuffy4255
# 23     #00CC2C         NaN   False           quacrunk
# 24         NaN         NaN   False           quikheet
# 25     #DAA520         NaN   False      thirteenjhm13
# 26     #8A2BE2         NaN   False            fluxayy
# 27     #00CCC5         NaN   False    recklessrelapse
# 28     #1DAFA3         NaN   False           iansynth
# 29     #FF69B4         NaN   False           avian141
# ...        ...         ...     ...                ...
# 12523  #00FF7F         NaN   False       dustin_clark
# 12524  #F497DE         NaN   False            bambiku
# 12525  #0000FF         NaN   False          khriz0571
# 12526      NaN         NaN   False        ryanjosephv
# 12527  #5F9EA0         NaN   False           argoncat
# 12528  #5F9EA0         NaN   False           argoncat
# 12529  #CD9FFE         NaN   False             xenoda
# 12530  #8D082A         NaN   False       pure__pazaak
# 12531  #1E90FF         NaN   False           immabard
# 12532  #9ACD32         NaN   False      creepincancer
# 12533  #8D082A         NaN   False       pure__pazaak
# 12534      NaN         NaN   False          howlucky4
# 12535  #1E90FF         NaN   False           immabard
# 12536      NaN         NaN   False          lederamar
# 12537      NaN         NaN   False  jared_jared_jared
# 12538  #FF0000         NaN   False        hurpyhooves
# 12539  #0000FF         NaN   False         ra1n_mak3r
# 12540      NaN         NaN   False          lederamar
# 12541  #FF69B4         NaN   False             moobot
# 12542  #00CCC9         NaN   False      superenergiez
# 12543  #FF69B4         NaN   False    zerotheabsolute
# 12544  #008000         NaN   False      20kills1night
# 12545      NaN         NaN   False         clamstrong
# 12546  #CC004B         NaN   False      bradpittshair
# 12547  #00CCC9         NaN   False      superenergiez
# 12548  #1E90FF         NaN   False           immabard
# 12549  #8A2BE2         NaN   False          rawfulma0
# 12550  #00CCC9         NaN   False      superenergiez
# 12551      NaN         NaN   False         clamstrong
# 12552  #00C9CC         NaN   False         dadnuggets
#
#                                                  message          room  \
# 0                                               PogChamp  clintstevens
# 1                                               PogChamp  clintstevens
# 2                                               PogChamp  clintstevens
# 3                                                HeyGuys  clintstevens
# 4                                                 WOOOOO  clintstevens
# 5                                               HI CLINT  clintstevens
# 6                                               PogChamp  clintstevens
# 7                                               hi clint  clintstevens
# 8                                                    yee  clintstevens
# 9                                              hes alive  clintstevens
# 10                            PogChamp WE IN IT PogChamp  clintstevens
# 11                                              PogChamp  clintstevens
# 12                                                   dad  clintstevens
# 13                                             hey clint  clintstevens
# 14                     @ClintStevens, hey wanna play OW?  clintstevens
# 15                               Clinty-winty-woo danAww  clintstevens
# 16                                               Kappa /  clintstevens
# 17                                         woooooooooooo  clintstevens
# 18                          is psn down for anyone else?  clintstevens
# 19                             hey @ClintStevens clintYo  clintstevens
# 20                                              PogChamp  clintstevens
# 21                                    hows i going clint  clintstevens
# 22                                              PogChamp           NaN
# 23                               heyyyyyyyyyyyyyyyyyyyyy  clintstevens
# 24                                                   DAD  clintstevens
# 25                                happy easter clintoris  clintstevens
# 26                                Clintu!! @Clintstevens  clintstevens
# 27                                    hey Clint TehePelo  clintstevens
# 28                                              HI CLINT  clintstevens
# 29                                              PogChamp  clintstevens
# ...                                                  ...           ...
# 12523                                            TriHard  clintstevens
# 12524                                       ori moon2WOW  clintstevens
# 12525                        really? i'll buy it then :D  clintstevens
# 12526                              I miss the real Clint  clintstevens
# 12527                                     you get emotes  clintstevens
# 12528                                                LUL  clintstevens
# 12529                            i love ori FeelsGoodMan  clintstevens
# 12530                                       FeelsGoodMan  clintstevens
# 12531                                       FeelsGoodMan  clintstevens
# 12532  Yeah @khriz0571 it is worth the money. It also...  clintstevens
# 12533                                        KonCha bard  clintstevens
# 12534                                      What happened  clintstevens
# 12535                                     pure OSsloth /  clintstevens
# 12536                                            !poinyd  clintstevens
# 12537                      How is everyone's night going  clintstevens
# 12538                                             clintB  clintstevens
# 12539                  its a conceptually beautiful game  clintstevens
# 12540                                            !points  clintstevens
# 12541  You have exactly 51 Clintpoints! Spam more in ...  clintstevens
# 12542                                         hello bard  clintstevens
# 12543                                     Clint is done?  clintstevens
# 12544                           Oh damn, did Clint quit?  clintstevens
# 12545                                      he just left?  clintstevens
# 12546  @hayleydanger that's cool to be able to say. S...  clintstevens
# 12547                                             superT  clintstevens
# 12548                                             enerGZ  clintstevens
# 12549                          now what do i do BabyRage  clintstevens
# 12550                                           enerGZ 7  clintstevens
# 12551  guys we have to make him happier as his twitch...  clintstevens
# 12552                                    Where did he go  clintstevens
#
#            timestamp  video-offset                              badges  bits  \
# 0      1492400397504           504               subscriber/12,turbo/1   NaN
# 1      1492400397903           903                                 NaN   NaN
# 2      1492400397909           909                        subscriber/3   NaN
# 3      1492400400077          3077                                 NaN   NaN
# 4      1492400400204          3204                            bits/100   NaN
# 5      1492400400918          3918                           bits/1000   NaN
# 6      1492400401903          4903                           premium/1   NaN
# 7      1492400402355          5355             subscriber/12,premium/1   NaN
# 8      1492400404154          7154                                 NaN   NaN
# 9      1492400404822          7822                        subscriber/6   NaN
# 10     1492400405202          8202              subscriber/3,bits/1000   NaN
# 11     1492400405522          8522                                 NaN   NaN
# 12     1492400405566          8566                                 NaN   NaN
# 13     1492400407217         10217                            bits/100   NaN
# 14     1492400407277         10277             subscriber/12,premium/1   NaN
# 15     1492400407703         10703                           premium/1   NaN
# 16     1492400408551         11551                                 NaN   NaN
# 17     1492400408764         11764                                 NaN   NaN
# 18     1492400409333         12333                           bits/1000   NaN
# 19     1492400409979         12979               subscriber/12,turbo/1   NaN
# 20     1492400410182         13182                            bits/100   NaN
# 21     1492400410652         13652              subscriber/3,bits/1000   NaN
# 22     1492400411357         14357               subscriber/6,bits/100   NaN
# 23     1492400411735         14735              subscriber/3,premium/1   NaN
# 24     1492400413877         16877                                 NaN   NaN
# 25     1492400414881         17881                        subscriber/3   NaN
# 26     1492400415785         18785                                 NaN   NaN
# 27     1492400416506         19506                            bits/100   NaN
# 28     1492400416678         19678              subscriber/6,bits/1000   NaN
# 29     1492400417356         20356                                 NaN   NaN
# ...              ...           ...                                 ...   ...
# 12523  1492411989083      11592083              subscriber/3,premium/1   NaN
# 12524  1492411990333      11593333              subscriber/3,bits/1000   NaN
# 12525  1492411990798      11593798                                 NaN   NaN
# 12526  1492412000700      11603700                                 NaN   NaN
# 12527  1492412000811      11603811                                 NaN   NaN
# 12528  1492412004178      11607178                                 NaN   NaN
# 12529  1492412007884      11610884  moderator/1,subscriber/12,bits/100   NaN
# 12530  1492412010796      11613796             subscriber/0,bits/10000   NaN
# 12531  1492412016262      11619262               subscriber/6,bits/100   NaN
# 12532  1492412019337      11622337              subscriber/0,premium/1   NaN
# 12533  1492412021532      11624532             subscriber/0,bits/10000   NaN
# 12534  1492412028543      11631543                                 NaN   NaN
# 12535  1492412031034      11634034               subscriber/6,bits/100   NaN
# 12536  1492412034583      11637583                                 NaN   NaN
# 12537  1492412036995      11639995              subscriber/0,premium/1   NaN
# 12538  1492412038137      11641137              subscriber/3,bits/1000   NaN
# 12539  1492412038379      11641379                                 NaN   NaN
# 12540  1492412038571      11641571                                 NaN   NaN
# 12541  1492412038643      11641643                         moderator/1   NaN
# 12542  1492412039371      11642371              subscriber/0,bits/1000   NaN
# 12543  1492412041573      11644573                                 NaN   NaN
# 12544  1492412042073      11645073                                 NaN   NaN
# 12545  1492412043746      11646746                                 NaN   NaN
# 12546  1492412044555      11647555                           premium/1   NaN
# 12547  1492412045457      11648457              subscriber/0,bits/1000   NaN
# 12548  1492412048234      11651234               subscriber/6,bits/100   NaN
# 12549  1492412050612      11653612              subscriber/0,premium/1   NaN
# 12550  1492412053563      11656563              subscriber/0,bits/1000   NaN
# 12551  1492412064410      11667410                                 NaN   NaN
# 12552  1492412065533      11668533              subscriber/3,premium/1   NaN
#
#          ...     msg-param-months   room-id       sent-ts style subscriber  \
# 0        ...                  NaN  86268118  1.492400e+12   NaN       True
# 1        ...                  NaN  86268118  1.492400e+12   NaN      False
# 2        ...                  NaN  86268118  1.492400e+12   NaN       True
# 3        ...                  NaN  86268118  1.492400e+12   NaN      False
# 4        ...                  NaN  86268118  1.492400e+12   NaN      False
# 5        ...                  NaN  86268118  1.492400e+12   NaN      False
# 6        ...                  NaN  86268118  1.492400e+12   NaN      False
# 7        ...                  NaN  86268118  1.492400e+12   NaN       True
# 8        ...                  NaN  86268118  1.492400e+12   NaN      False
# 9        ...                  NaN  86268118  1.492400e+12   NaN       True
# 10       ...                  NaN  86268118  1.492400e+12   NaN       True
# 11       ...                  NaN  86268118  1.492400e+12   NaN      False
# 12       ...                  NaN  86268118  1.492400e+12   NaN      False
# 13       ...                  NaN  86268118  1.492400e+12   NaN      False
# 14       ...                  NaN  86268118  1.492400e+12   NaN       True
# 15       ...                  NaN  86268118  1.492400e+12   NaN      False
# 16       ...                  NaN  86268118  1.492400e+12   NaN      False
# 17       ...                  NaN  86268118  1.492487e+12   NaN      False
# 18       ...                  NaN  86268118  1.492400e+12   NaN      False
# 19       ...                  NaN  86268118  1.492400e+12   NaN       True
# 20       ...                  NaN  86268118  1.492400e+12   NaN      False
# 21       ...                  NaN  86268118  1.492400e+12   NaN       True
# 22       ...                  7.0  86268118           NaN   NaN       True
# 23       ...                  NaN  86268118  1.492400e+12   NaN       True
# 24       ...                  NaN  86268118  1.492487e+12   NaN      False
# 25       ...                  NaN  86268118  1.492400e+12   NaN       True
# 26       ...                  NaN  86268118  1.492400e+12   NaN      False
# 27       ...                  NaN  86268118  1.492400e+12   NaN      False
# 28       ...                  NaN  86268118  1.492400e+12   NaN       True
# 29       ...                  NaN  86268118  1.492400e+12   NaN      False
# ...      ...                  ...       ...           ...   ...        ...
# 12523    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12524    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12525    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12526    ...                  NaN  86268118           NaN   NaN      False
# 12527    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12528    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12529    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12530    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12531    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12532    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12533    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12534    ...                  NaN  86268118           NaN   NaN      False
# 12535    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12536    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12537    ...                  NaN  86268118           NaN   NaN       True
# 12538    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12539    ...                  NaN  86268118           NaN   NaN      False
# 12540    ...                  NaN  86268118  1.492412e+12   NaN      False
# 12541    ...                  NaN  86268118           NaN   NaN      False
# 12542    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12543    ...                  NaN  86268118           NaN   NaN      False
# 12544    ...                  NaN  86268118           NaN   NaN      False
# 12545    ...                  NaN  86268118  1.492437e+12   NaN      False
# 12546    ...                  NaN  86268118           NaN   NaN      False
# 12547    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12548    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12549    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12550    ...                  NaN  86268118  1.492412e+12   NaN       True
# 12551    ...                  NaN  86268118  1.492437e+12   NaN      False
# 12552    ...                  NaN  86268118           NaN   NaN       True
#
#                                               system-msg    tmi-sent-ts  \
# 0                                                    NaN  1492400411953
# 1                                                    NaN  1492400412324
# 2                                                    NaN  1492400412358
# 3                                                    NaN  1492400414521
# 4                                                    NaN  1492400414643
# 5                                                    NaN  1492400415321
# 6                                                    NaN  1492400416367
# 7                                                    NaN  1492400416795
# 8                                                    NaN  1492400418611
# 9                                                    NaN  1492400419259
# 10                                                   NaN  1492400419658
# 11                                                   NaN  1492400419986
# 12                                                   NaN  1492400420003
# 13                                                   NaN  1492400421676
# 14                                                   NaN  1492400421738
# 15                                                   NaN  1492400422124
# 16                                                   NaN  1492400422956
# 17                                                   NaN  1492400423207
# 18                                                   NaN  1492400423783
# 19                                                   NaN  1492400424440
# 20                                                   NaN  1492400424601
# 21                                                   NaN  1492400425098
# 22     tuffy4255\sjust\ssubscribed\swith\sTwitch\sPri...  1492400425819
# 23                                                   NaN  1492400426175
# 24                                                   NaN  1492400428343
# 25                                                   NaN  1492400429297
# 26                                                   NaN  1492400430232
# 27                                                   NaN  1492400430968
# 28                                                   NaN  1492400431129
# 29                                                   NaN  1492400431818
# ...                                                  ...            ...
# 12523                                                NaN  1492412003509
# 12524                                                NaN  1492412004770
# 12525                                                NaN  1492412005223
# 12526                                                NaN  1492412015156
# 12527                                                NaN  1492412015253
# 12528                                                NaN  1492412018616
# 12529                                                NaN  1492412022358
# 12530                                                NaN  1492412025235
# 12531                                                NaN  1492412030719
# 12532                                                NaN  1492412033752
# 12533                                                NaN  1492412035994
# 12534                                                NaN  1492412042958
# 12535                                                NaN  1492412045479
# 12536                                                NaN  1492412048986
# 12537                                                NaN  1492412051454
# 12538                                                NaN  1492412052592
# 12539                                                NaN  1492412052824
# 12540                                                NaN  1492412053027
# 12541                                                NaN  1492412053114
# 12542                                                NaN  1492412053810
# 12543                                                NaN  1492412055977
# 12544                                                NaN  1492412056534
# 12545                                                NaN  1492412058209
# 12546                                                NaN  1492412058985
# 12547                                                NaN  1492412059905
# 12548                                                NaN  1492412062562
# 12549                                                NaN  1492412065070
# 12550                                                NaN  1492412068024
# 12551                                                NaN  1492412078870
# 12552                                                NaN  1492412079987
#
#        turbo    user-id  user-type
# 0       True  109086033        NaN
# 1      False   57027344        NaN
# 2      False   35950973        NaN
# 3      False  131137126        NaN
# 4      False  143565518        NaN
# 5      False  111283120        NaN
# 6      False  139757133        NaN
# 7      False   27862377        NaN
# 8      False   94120565        NaN
# 9      False   76465212        NaN
# 10     False   56544921        NaN
# 11     False   67468924        NaN
# 12     False   79057669        NaN
# 13     False  126732184        NaN
# 14     False   27862377        NaN
# 15     False   47529299        NaN
# 16     False  104820006        NaN
# 17     False  149667282        NaN
# 18     False   29503089        NaN
# 19      True  109086033        NaN
# 20     False   30875824        NaN
# 21     False   25439059        NaN
# 22     False   56447760        NaN
# 23     False   76030467        NaN
# 24     False  149667282        NaN
# 25     False   35950973        NaN
# 26     False   72532191        NaN
# 27     False   30875824        NaN
# 28     False    7212792        NaN
# 29     False   30672515        NaN
# ...      ...        ...        ...
# 12523  False  100258639        NaN
# 12524  False  103531410        NaN
# 12525  False   86084677        NaN
# 12526  False  103725824        NaN
# 12527  False   93756801        NaN
# 12528  False   93756801        NaN
# 12529  False   53569589        mod
# 12530  False  131847836        NaN
# 12531  False   56592212        NaN
# 12532  False   73306914        NaN
# 12533  False  131847836        NaN
# 12534  False     136040        NaN
# 12535  False   56592212        NaN
# 12536  False  150591934        NaN
# 12537  False  111719683        NaN
# 12538  False   39797784        NaN
# 12539  False   78441557        NaN
# 12540  False  150591934        NaN
# 12541  False    1564983        mod
# 12542  False   30477322        NaN
# 12543  False   46052354        NaN
# 12544  False   87890295        NaN
# 12545  False   79495391        NaN
# 12546  False  120158706        NaN
# 12547  False   30477322        NaN
# 12548  False   56592212        NaN
# 12549  False   44508113        NaN
# 12550  False   30477322        NaN
# 12551  False   79495391        NaN
# 12552  False  124583694        NaN
#
# [12461 rows x 27 columns]

# %%
punctuation_chars = ".,!?:;\"'-~|[]()/\\\n"

messages = d.message.str.lower()
def remove_punctuations(s):
    s = ''.join([i for i in s if i not in frozenset(punctuation_chars)])
    return s
messages = messages.apply(remove_punctuations)
messages
# Out:
# 0                                                 pogchamp
# 1                                                 pogchamp
# 2                                                 pogchamp
# 3                                                  heyguys
# 4                                                   wooooo
# 5                                                 hi clint
# 6                                                 pogchamp
# 7                                                 hi clint
# 8                                                      yee
# 9                                                hes alive
# 10                              pogchamp we in it pogchamp
# 11                                                pogchamp
# 12                                                     dad
# 13                                               hey clint
# 14                         @clintstevens hey wanna play ow
# 15                                   clintywintywoo danaww
# 16                                                  kappa
# 17                                           woooooooooooo
# 18                             is psn down for anyone else
# 19                               hey @clintstevens clintyo
# 20                                                pogchamp
# 21                                      hows i going clint
# 22                                                pogchamp
# 23                                 heyyyyyyyyyyyyyyyyyyyyy
# 24                                                     dad
# 25                                  happy easter clintoris
# 26                                    clintu @clintstevens
# 27                                      hey clint tehepelo
# 28                                                hi clint
# 29                                                pogchamp
#                                ...
# 12523                                              trihard
# 12524                                         ori moon2wow
# 12525                             really ill buy it then d
# 12526                                i miss the real clint
# 12527                                       you get emotes
# 12528                                                  lul
# 12529                              i love ori feelsgoodman
# 12530                                         feelsgoodman
# 12531                                         feelsgoodman
# 12532    yeah @khriz0571 it is worth the money it also ...
# 12533                                          koncha bard
# 12534                                        what happened
# 12535                                        pure ossloth
# 12536                                               poinyd
# 12537                         how is everyones night going
# 12538                                               clintb
# 12539                    its a conceptually beautiful game
# 12540                                               points
# 12541    you have exactly 51 clintpoints spam more in c...
# 12542                                           hello bard
# 12543                                        clint is done
# 12544                               oh damn did clint quit
# 12545                                         he just left
# 12546    @hayleydanger thats cool to be able to say som...
# 12547                                               supert
# 12548                                               energz
# 12549                            now what do i do babyrage
# 12550                                             energz 7
# 12551    guys we have to make him happier as his twitch...
# 12552                                      where did he go
# Name: message, dtype: object

# %%
uniques = set(messages)
uniques
# Out:
# {'',
#  'clint can you do a jumping jack i will sub',
#  'practice bottom of the well',
#  'if youre not using a vape at this point clint wtf are you doing with your life @clintstevens',
#  'natural',
#  'clint got rid of the dampe emote',
#  'i like the name cheep',
#  'split',
#  'autism joke sux',
#  'did you not look at obs for that',
#  'youre a shitty character',
#  'oh man feelsbadman  whats the uptime i was hoping for an ongoing run @clintstevens',
#  'what ',
#  'we got telescopes as eyes',
#  'that last one is good though kappa',
#  'maybe thats why hes good 🤔',
#  'saved clintrem',
#  'typical racists fighting for who owns the most blacks cmonbruh',
#  'ace combat',
#  '@jared_jared_jared make it a fair fight allow both of you one melee weapon each',
#  'few games of deceit biblethump',
#  'ass',
#  'grill donator o',
#  '@clintstevens what are these splits',
#  'nadiah @mchamy',
#  '@cinnamon_se pogchamp <3',
#  'didnt you drop out of high school',
#  'says restart',
#  '@clintstevens how do i beat a laser camping falco',
#  'dammit 2 staff in the chat',
#  'will you tickle my grundle clint',
#  'distgibe clints clintfug clintred clintred clintred',
#  'pogchamp clutch pogchamp',
#  'insecure',
#  'clintred clintred clintred clintred clintred clintred clintred clintred clintred clintred clintred clintred clintred',
#  '21 months holy shit what a guy',
#  'youll still feel better doing something different and you need the endgame',
#  'random n64 game',
#  'clintfug clints clintw trust no one not even yourself',
#  'we only want perfection from you clint',
#  'fucking genius',
#  'working late night shifts lul',
#  'clintchoking clintchoking clintchoking clintchoking',
#  'hey clint* @clintstevens',
#  'dont fucking remove bae rem',
#  'cheepcheep clintcheep cheepcheep clintcheep',
#  'dive grass lul',
#  'clintrem clintj',
#  'clintfug pogchamp',
#  '@dprezoh death to normies cirbaka',
#  'i look like a diseased version of a regular person',
#  '@clintstevens good luck on the run im feeling good tonight pls s a c me',
#  '@lpzeldagamer clintyo',
#  'clinthi clintyo',
#  'whats the name of the sanic rpg on ds',
#  'looks like a great value chuck',
#  'y u back in the dark bro',
#  'duo stream with tyler1',
#  'clints your president 🤔',
#  'dgdbdbjss',
#  'venrule pls',
#  'makar come backkkkkkkkkkk',
#  'why you in bugs life',
#  'forsen chat is thee worst',
#  'nice try',
#  'clint i count on you for killing that darned ganon he stole my crayons clintw',
#  'bring back a good rayman game',
#  'you got rid of makar you fucking bitch',
#  '@remri no pbs for at least a year v',
#  '@clintstevens theres an audio clip of it',
#  'where is my fucking chocolate',
#  'let me see this 400 dollar shirt',
#  'please',
#  'what the whole point of sonic adventure 2 was to introduce shadow',
#  'its a conceptually beautiful game',
#  'lol you have nooses laying around',
#  'ohhhh not the real venice',
#  'clintfug nice clintw emotes clintfug',
#  'r u gonna eat peanut butter and bread again today or oskomodo oskomodo',
#  'clintclean clintclean clintclean clintfug clintfug clintfug',
#  'feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar feelsmakar',
#  'oh god no lul',
#  'clintfug wow',
#  'holy shit youre actually green for once clit',
#  '@xenoda wait what was clintk',
#  'clint do u even have fun streaming anymore',
#  'godlike chickens',
#  'mods',
#  '@clintstevens you triggering chat they love the game myself included',
#  'is psn down for anyone else',
#  'sure',
#  'isg is hard',
#  'whatever you feel like doing clint ill still be here and i bet a bunch of people will too seemsgood',
#  'clints career going south notlikethis',
#  'the lamp',
#  'aw clint said hi to me sparelewd',
#  'im not genuine enough clints clintb',
#  'just a guy lul',
#  'were gonna try curly feelsgoodman',
#  'stonelightning',
#  'clint ur gay',
#  'you need to stop resetting',
#  'at least we still have clintt',
#  '@oopsspaghetti 2 frame',
#  'al horford had a career high 7 rebounds tonight',
#  'you sound tired @clintstevens ',
#  'distsmile distsmile distsmile',
#  'mcsleuthbrgr didnt miss it ',
#  'chew',
#  'clintfug clint2 clintw',
#  'thats me feelsbadman',
#  'whats up clint@clintstevens',
#  'waht was that voice lul',
#  'i tell girls i hang out here they get wet',
#  'bambi koncha',
#  '@amazhs heyguys',
#  'nobody',
#  'he didnt read it',
#  'clint accepts cancer wutface',
#  'clintd is dead',
#  'a',
#  'dont move to colorado its terrible',
#  '@clintstevens pharah only',
#  'rtz',
#  'uptime',
#  '@silkymoostache hes perma banned',
#  '@dprezoh make sure to distort his face even more',
#  'what a god lul',
#  'lol clint you heard wrong residentsleeper',
#  '@thirteenjhm13 ty ty',
#  'worked on easter got good tips kreygasm',
#  'trihard  🏀 clintw',
#  'cya dave > ',
#  '@zefrenchgreg practice',
#  'dansgame dansgame dansgame',
#  'you have to shield and target on the second frame of explosion',
#  'springysheep i hate when i get that feminine itch it also makes my balls smell',
#  'the only time i saw him complete a run was when he had the record coming and a rock landed on his head and fucked him over',
#  'clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen clintgreen',
#  'autist',
#  'httpimgurcomanduhn please add my twin brother clintw',
#  'clintc we miss you clint clintc clintc we miss you clint clintc clintc we miss you clint clintc clintc we miss you clint clintc',
#  'did you fire some mods or you were just having a moment last night',
#  'sonic adventure 3 kippa',
#  'jeep jeep',
#  'bambiku  ',
#  'what re these splits rn',
#  'is this a weeb chat yet',
#  'that is a video game for the nes',
#  'give makar back clintchoco clintchoco clintchoco clintb clintb',
#  'louise',
#  'clintgreen clintred',
#  'wtf am i watching',
#  'reset time oh boy',
#  'lmaooooooooooo',
#  'vohiyo hello nawtypaticake',
#  'clinthi clinthi clinthi clinthi',
#  'stream',
#  'we can make it up in spirit clintg',
#  'clints clintrem clints clintrem clints clintrem clints clints',
#  '@noobberry daccord',
#  'clintcheep you made me clint clintcheep you made me clint clintcheep you made me clint clintcheep you made me clint clintcheep you made me clint',
#  'kkona sports 🍺',
#  'pleaseno pleaseno pleaseno pleaseno',
#  'whats the wr in this game',
#  'do what you want dude its your damn life',
#  '10 pushups every reset',
#  '@clintstevens get an anti melee emote',
#  '@clintstevens will you save time at light medallion',
#  'clint are traps still gay',
#  'are you gonna stop streaming after this run',
#  'giveplz imglitch takenrg',
#  'the midna is midna so i love it',
#  '@noobberry ',
#  'optical illusion notlikethis',
#  'plebs > mods',
#  'yolo gaurd amiright',
#  '@allfridaysmatter f',
#  '@superenergiez he still wont mod you too feelsbadman',
#  'cause this is the urn',
#  'wait',
#  'clintlul',
#  'liaison @clintstevens',
#  '@xenoda pogchamp <3',
#  'cole minor',
#  'i thought rem got u so much puss',
#  'hurpy clinthi',
#  'clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy clintfug fuck me duddy',
#  'cheepceep',
#  'prob gotta refresh',
#  'its your fuel',
#  'will u lwt my dick slide in your mouth',
#  '@squadeep you can get 1080p 144hz for that money',
#  'rtz chat is far worse @clintstevens',
#  'do what chuck does and fap on stream',
#  'sorry autismo feelsbadman',
#  'what happened with terps',
#  '@clintstevens did you always on some level want to become an oot speedrunner or are you content with being 2nd place cuck',
#  'usted mathmatica',
#  'cheer100 its ok man we enjoy the stream as long as youre doing what you like',
#  'curly lyl',
#  'oh damn did clint quit',
#  'thank you clunt for teach teaching me who to read',
#  'pls clap ',
#  '@mopshead kappa',
#  'little kid games i wonder who enjoys those on a day to day basis clintt',
#  'who the is the producer',
#  'this phatty money pogchamp',
#  'are you really gonna continue this',
#  'l i l b i t c h',
#  'rtzw',
#  'cheepcheep',
#  'accepted emotes pogchamp',
#  'oh what i would do to slap kaceys funbags around kreygasm',
#  'clint literally michael vick stevens',
#  'goodnight dood',
#  'clint has shit taste failfish',
#  'start smoking hybrids feelsamazingman',
#  '@clintstevens hey retard no one said to get rid of clintyo',
#  'never practice dampe',
#  'chucks cousin',
#  'paper mario',
#  '12m 20s ',
#  'clint when did you get the new emotes',
#  'dave opieop',
#  'hey curly',
#  'i love you clint',
#  'he saw you through every hedge',
#  'pogchamp pogchamp pogchamp pogchamp',
#  'clintw clints',
#  's c o t l a n d pepepls',
#  'rulefive',
#  'good vibes ',
#  'clintfug wixb',
#  'so much for being a god',
#  'xenoda do you let anyone say its impossible yes we all want to ride it but dont let people say otherwise',
#  'no makar clintb no clintk clintb all thats left is clintchoking',
#  'elegiggle bruh',
#  'i feel you clintfug you wanna feel me clintfug clints',
#  'clintc clintc clintc clintc clintc clintc clintc clintcheep clintcheep clintcheep clintcheep clintc clintc clintc clintc',
#  '@hayleydanger is a fake ginger',
#  'i bet highschool me could beat you',
#  'clintc clintcheep clintc clintcheep clintc clintcheep clintc clintcheep clintc clintcheep clintc clintcheep clintc clintcheep clintc clintcheep clintc clintcheep clintc clintcheep clintc',
#  'stop reseting dude plz thankegg',
#  'clintstevens whens the breath of the wild 100% speedrun kappa',
#  '@boe_jovy  4head',
#  '@abssgaming dont listen to them clintchoco',
#  'xc',
#  'press 🅱️ for bowl',
#  'rejected',
#  'currently wearing shirt with deadmau5 on it ',
#  'koncha bard',
#  'those boobs',
#  'pleb only mode pls',
#  'tomorrow will be the day',
#  'his internet troll voice was more masculine than hell ever be feelsbadman',
#  'we are just as bad',
#  '@bambiku what if im neither roowhat clintcute clintt',
#  'clintchoco clintchoco clintchoco clintj clintj clintj clintrem clintrem clintrem clintk clintk clintk',
#  'agent',
#  'clint ill be able to play f13 on the weekends i wont be able to play every night like before clintb',
#  'the emote is so bad holy shit',
#  '@clintstevens the only reason i was subbed to you was for makar',
#  'im just glad makars dead',
#  'moon2gasm moon2l',
#  '@clintstevens hey love d',
#  'vohiyo hello rawful',
#  'clintrem clintrem clintrem clintrem clintrem',
#  '@dachshundbob now now',
#  'nice',
#  'sup man how you doing',
#  'vibruto',
#  'it was trump and it was a twitter post',
#  'you dont like lion king dansgame get your panties out of a bunch swiftrage',
#  'clint2 clint2',
#  'clintfug clintw clintfug clintw clintfug clintw clintfug clintw clintfug clintw clintfug clintw',
#  'reck7',
#  'loboscringe',
#  'waddup clint',
#  'borewatch',
#  '@oskomodo just like cirno emotes minglee',
#  '@mybsurchin theres power hungry attention seeking bitch mods that take over a stream thats chill otherwise',
#  '@classicclara lol dont get baited by him pretending to care about the negativity',
#  'fuck you',
#  'pumpkin hill theme kreygasm',
#  'shinycutesylveon boob emote is the classic',
#  '¯_ツ_¯ inurjeezy',
#  'reckfuls live pogchamp',
#  'lul drama',
#  'clintcheep clintcheep clintcheep clintcheep clintcheep clintcheep clintcheep clintcheep clintcheep clintcheep',
#  'chao racing and karate clintw',
#  'lfmao',
#  'clint has sleep apnea clintb',
#  'mario tennis feelsgoodman',
#  'those 2o secs wouldnt matter if you would stop fucking up within the first 15 mins',
#  'xenoda heres a 14 hz monitor',
#  'so when is nier automata @clintstevens its an amazing massterpiece',
#  'what did i say',
#  'so you mean the black makret',
#  'kawhi leonard > lbj',
#  'i laugh whenever someone says to kill myself',
#  '@parttmer clintm',
#  'make a camel toe emote buddy',
#  'lollll',
#  'giveplz dxcat takenrg',
#  'damn is clint in a darker room no backlight',
#  'clintyo feelsbadman 🔫',
#  'dead mao 5 is chinas jackson 5 kappa',
#  '+4 restart',
#  'call medli shes crying biblethump',
#  '@clintstevens then pick less shitty games lul',
#  'did he remove rem',
#  'resets = more clintc i dont see the problem',
#  'do the better clint u can do it',
#  'alt j',
#  'ya',
#  '@cheezeburgerstick youve been spamming that message literally for over an hour he doesnt give a fuck',
#  'cmonbruh the efuck',
#  'you mean the chaos emeralds',
#  'practice',
#  'clintc thanks for finding us clintc',
#  'just a local speedrunner clintw',
#  'im a pleb hit me up',
#  'hey clint how are you today',
#  'ves is fun to play with',
#  '@clintstevens where the fuck is makar what did you do to him clint clints clintchoco',
#  '@clintstevens xc means cross country and tc means track and field lol',
#  '@clintstevens no reset just to dampe',
#  'zelda wants the stick',
#  'clint your eyebrows look great today <3 he wont read this',
#  'soccer is awesome haters',
#  '@xenoda no its gone bro',
#  'how have the runs been going today smorc smorc smorc smorc smorc',
#  'literally no one used makar',
#  '@clintstevens ever play sky odyssey',
#  'eventually',
#  'i got the clap from doing that',
#  'autsm kreygasm',
#  'always tired clints depressed clintb',
#  'purpleenza',
#  'zfg gets this all of the time',
#  'clant son dont be sad these cucks are just that cucks',
#  'subs are worse than plebs in all honesty',
#  'ez',
#  'or did you said to it what i told them that answer who told me that',
#  'where is clintm',
#  'abss true clintcute',
#  'highlighted',
#  '@coolguy7211 same ive met so many hoes and we bond over clint stevens believe that',
#  'what killed the last run',
#  'smile clintfug',
#  'clintcheep clintc clintc clintcheep clintc clintcheep clintc',
#  'ppmd kreygasm',
#  'clint can we see your inputs',
#  'early sac tho',
#  'clint you look so spooky',
#  'i shattered my bowl just 10 minutes ago at least i have my 4 month subscriber message though',
#  'fuck the haters',
#  'tfw eating pizza rolls while watching clunt fail at speedrunning zelda feelsgoodman',
#  'i wont sub now because makar is gone',
#  'practice gerudo hess',
#  'clintcheep is gonna become the new clintm notlikethis',
#  'youre always fucking tired seen a doctor',
#  'hahaa i jizz in my pants btw hahaa',
#  'swiftrage update swiftrage rip swiftrage command swiftrage',
#  'lulululullulul',
#  'mor chicken',
#  'you got this shit clint',
#  'clintchoking clints clintfug',
#  '@clintstevens on avarage how many subs do you get a month',
#  '@xenoda see',
#  'another',
#  'can we at least get the sloth emote',
#  'whats your second favorite game to speedrun',
#  'clint would you sell a viewer a pair of your dirty socks for $100',
#  'talk about the nba playoffs',
#  'this is my favorite part of links adventure',
#  'pogchamp juke',
#  '@clintstevens have you heard any neighbors bang each other yet',
#  'they cast puncay to play that character',
#  'babyrage babyrage babyrage babyrage babyrage babyrage babyrage babyrage babyrage babyrage',
#  'you are in my heart',
#  'i feel you',
#  '@clintstevens people are requesting a trap channel in the discord ',
#  'clintm clintm clintm clintm clintm clintm clintm',
#  'cluntism',
#  'no clintweeb cirlaugh',
#  'go to guitar center or msusic place for your next mic purchase',
#  '@clintstevens take it easy',
#  'clint is mormon',
#  'clintrem',
#  'play botw',
#  'clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug',
#  'says the zelda speedrunner',
#  '@dustin_clark she is like married',
#  '@clintstevens play minecraft pleeeeassssseeee',
#  '@actuallynav fuck you kid',
#  '@clintstevens have you ever tried putting goldbond foot powder on your balls it feels like 1000 angles gently kissing them',
#  'they would just ruin kotor idk why anyone wants it to be brought back itd be shit just like every other modern bioware game',
#  'who says that lol',
#  '@xenoda whats it at',
#  'cheer up hahaa',
#  '@clintstevens you got rid of makar but added that shitty ass fucking chicken i swear to god clint i hope you get 50th try dampe every run you skank this is god damn revolting im disgusted unsubbing notlikethis',
#  '@noobberry clintcheep',
#  '@mna27 ow 🤔',
#  'game',
#  'clintfuh',
#  '@mopshead nah dude his irl streams are lit',
#  'catch them doing what smoking legal weed',
#  'vohiyo',
#  'dont reset please ',
#  'clintcheep clintc clintcheep clintc clintcheep clintc clintc clintcheep clintc clintcheep clintc clintcheep clintc clintcheep',
#  'all night p ractice pogchamp',
#  'clintfug clintcheep clintfug clintcheep clintfug clintcheep clintfug clintcheep clintfug clintcheep clintfug clintcheep clintfug clintcheep',
#  'they said you can pb today pogchamp',
#  'have you ever messed up there and had to reread all that stuff the owl says',
#  'scammed',
#  'helo clint and chat heyguys',
#  '1st try incoming',
#  'or is that on an older run',
#  'its a meme in stream form',
#  '@clintstevens even if u said nothing we would see it',
#  '*split is bottle* next splits with bommerang something is wrong',
#  'appreciate is spelt wrong in you subscriber alert 4head',
#  'mipha',
#  'ss',
#  'clintfug clints clintc clintfug clints clintc clintfug clints clintc',
#  'dick hand lul',
#  'i finished zelda i on nes few weeks ago it was really really tough',
#  'clintfug clints clintgasm clintfug clints clintgasm clintfug clints clintgasm clintfug clints clintgasm',
#  'bye bye clint',
#  'snapple',
#  '^',
#  '@oversolar good point lul',
#  'but nahh fuck those guards this is the run stonelightning stonelightning stonelightning',
#  'clintcheep catch us clint clintcheep',
#  'journaling',
#  '@coolguy7211 play 3 and 4 first or u will love p5 so much u wont enjoy 3 and 4',
#  'ssx',
#  'yo zombiechou',
#  '@xenoda moonmoon fags ruined this channel with your smug ideas dansgame',
#  'clint chows stevens',
#  '@honeymustxrd wtf i got a 24 hour ban from your stream for saying you look cute like idek what happened is that not ok to say in your stream @honeymustxrd',
#  'bleedpurple bleedpurple bleedpurple',
#  '@clintstevens you ever try any %',
#  '2spooky',
#  'fire moobot',
#  'clintfug clints clintk',
#  '@missgeechan wtf seriously lol',
#  '@pikafunrun kappapride ',
#  'clint just practicing then i guess i was confused by the splits i saw lol',
#  'how far has he gone tonight fam',
#  'clint why dont you learn a new run you got the skill',
#  'but you n witwix have the best chats on twitch',
#  '@clintstevens did you graduate highscool you mugg',
#  'thanks for the explanation',
#  'you *** me clint',
#  '@clintstevens he was mad i didnt have cigs on me',
#  'its called sarcasm kill yourself',
#  '@clintstevens just brake through the beginning it helps a lot',
#  '@thirteenjhm13 thank you for this',
#  'hello chickens my old friend ive come to gather you again because child 1 is softly creeping lost my pb while i was sleeping and the red split that was planted in my brain still remains within the sound of chickens ',
#  'ily',
#  'dark is more chill',
#  'what is the next major fail of pb ',
#  'new mods',
#  'ye its awful',
#  'long ass sub right there',
#  'the producers told me clint is gonna pb today pogchamp',
#  '@abbbit drink water',
#  'botw for makar',
#  'anyone know if og mudbone streams',
#  'when i get made i turn black',
#  'whyyyy would u ever',
#  'hes trolling guys',
#  'later',
#  'havent been here for a while but have u moved out',
#  'coolstorybob bob lives in our heart coolstorybob',
#  'dont you dare touch rem',
#  'chat = drama llama cheepcheep chat = drama llama cheepcheep chat = drama llama cheepcheep',
#  'clintchoco clintk  get rid of them',
#  'we only want you to die cause we love you bro',
#  'fniseemsgoodman',
#  'i aint gonna let it get to me',
#  'feelsbadman what we enjoy is your 9 to 5 feelsbadman',
#  'usepoints',
#  'dcs world kappa a f14 module is on the way',
#  '@xenoda no heteros here roocop',
#  'dew it dp',
#  'do this kid look like an lesbian to anyone else',
#  'cheer up',
#  'can we just do live stream of tinder swipes',
#  'cummies for clinties',
#  'im a paparazzi',
#  'hamy lul',
#  'i send him boobs all the time @4eign',
#  '@fluxayy yo',
#  'clintb @deonte1101',
#  'never refresh',
#  'can i milk your tits @clintstevens',
#  '@classy_kangaroo everyone except blur does they keep him in the basement and pay him in animal crackers and hand jobs',
#  'yay clint',
#  '@clintstevens sup buddy what did you do with your day today for jesus&eggs holiday',
#  'yeah but rembrandt was heavily influenced by renaissance painters lol',
#  'isnt squishy the janitor tho @clintstevens kappa',
#  'sneakyfedora',
#  'cause you were smashing poon amiright',
#  'u suk',
#  'gold split pogchamp pogchamp',
#  'c h a o s c o n t r o l',
#  'cummie cums for clinty lul',
#  'alex19feelsmagic',
#  'kid is awake pedobear get him',
#  '@clintstevens im getting people ready for ow later tonight',
#  'should have just taken a vote you evil dictator',
#  'lol tue',
#  'big la man finally graces us with the stream',
#  'mods are autismo',
#  'you dont have to clint lmao',
#  'they hate weebs',
#  'clintfug clints clintcheep put it down clint',
#  'wait did you move to la to become a scientologist',
#  'eventually kappa',
#  'you dont say youre really well at zelda do you',
#  'enerjebic please clap',
#  'just make a 4x4 version of clintc',
#  'punw clintw',
#  'clint if you take this run seriously and make it a strong run for once ill help you get super fucked up and go to a game afterwards my dude',
#  'you take a good rest clint ',
#  'no do not unleash the scab wutface',
#  'dicks',
#  'clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug',
#  'you dont get custom computers anywhere',
#  'thats all hes doing dumbass',
#  'i missed the old clint the controller clint kappa',
#  'when we raid are we gonna do date clint clintfug',
#  '@clintstevens have you got your moneys worth from oot',
#  'we need a clinthard emote',
#  'i love me some grean kappa',
#  'if only we could get this fishing in an actual run wtf',
#  'so you can pick up chicks easier',
#  'clintfug clintrem',
#  'suck a bag of dick stevens',
#  'cheer135 @clintstevens dont even worry about it they say shit like that cuz they jealous hate us cuz they anus they dont got what you have',
#  'its true 4head',
#  'green feelsgoodman',
#  'gold then red',
#  'clint u excited for new lorde album ',
#  'clintautist',
#  'pogchamp pogchamp pogchamp pogchamp pogchamp',
#  'woops',
#  'i hope they do take the trihard emote away',
#  'clintfug is growing on someone pogchamp',
#  'play mount your friends',
#  'clintfug clintcheep clintfug harestare cheepchee clintgasm',
#  'cheer100 clint whats your favorite easter candy',
#  'little kid',
#  'clintfug this is so bad its amazing',
#  'dew it no balls',
#  'cheepcheep clintcheep cheepcheep clintcheep cheepcheep',
#  'vohiyo hello ivo_ovalle',
#  'what are the yellow times',
#  'i used clintyo in vgbootcamp today and got at least 1 other clintyo back my chat experience is ruined',
#  'makar was gay',
#  'subscirber',
#  'what up',
#  'we want dampe emote again',
#  '🖕🖕🖕🖕🖕🖕🖕🖕🖕🖕🖕🖕🖕🖕🖕🖕🖕',
#  'are you implying you wouldnt have a circlejerk with this chat',
#  'cj miles with the last shot lul',
#  'xenoda clintrem',
#  'super monkey ball dog fight',
#  'yes that trick has been missed so often lately',
#  'cheepcheep cheepcheep cheepcheep cheepcheep cheepcheep cheepcheep cheepcheep',
#  'wait wait wait',
#  'dampe definitely should not have been removed',
#  'lu',
#  'subs lul',
#  'current game is  the legend of zelda ocarina of time',
#  'if you could flip a switch and have everyone be nice most of the time in chat would you',
#  'blink_templar twwhd is 130 now not the gc one though',
#  '@lpzeldagamer i like it ',
#  'masster of cocks',
#  'sabaping where is my chocolate',
#  'all makar',
#  'feelsbirthdayman',
#  'clinta',
#  'clint do you ever stop and think about the drive you have for this game what if you had this much drive for something that made you wayyy more money than this',
#  'clintc chickens practice clintc',
#  '@kindalur your mom made me pasta last night pogchamp',
#  'yesssss',
#  '@estormudo  why would i be b anned',
#  'theyw ould definitely reject it',
#  'how to are u 24 min ahead',
#  'jesus',
#  'koncha',
#  'clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep',
#  'clintc hello clintc again clintc clint clintc',
#  'subbing in 2k17 lul',
#  'hellooo',
#  'wow its almost like hes playing a game and cant always read chat',
#  '@clintstevens i hate you',
#  '@clintstevens your position on sm64 rng is like the coal miners',
#  'clintfug date clint',
#  'chaos',
#  'wot did u say u lil shit clintfug',
#  'dont hate us feelsbadman',
#  'a green number for once',
#  'any moon moon subs',
#  'we want cluntbot dansgame',
#  'fucking scrub lul',
#  'switch to a sativa strain kappa',
#  'see nobody pressed 1 d',
#  '🐝💐🍪🎂🍰',
#  '@phlas5 que elles mange',
#  'fucking wasted',
#  'this run sucks just reset idoit',
#  'clintj clintj clintj clintj clintj clintj clintj clintj',
#  'dead mao zhedong five',
#  'its all gone @deonte1101 clintb',
#  'lul dave',
#  'bring back makar',
#  'clints selfesteem for positive comments feelsbadman',
#  'all this resetting already has me asleep residentsleeper',
#  '@clintstevens do you have people just come up to you and be like hey i watch your stream',
#  'i do @chuckthegypsy',
#  'war thunder',
#  'chris paul has herpes',
#  'trihard the new kappa',
#  'ive seen some fun new tricks in botw lately',
#  'slave to the grind feelsbadman 🔫',
#  'makar is gone',
#  '@hayleydanger wow poor cyrus clintb',
#  'clintred clintj clintred',
#  'emote',
#  'w o r k lul',
#  'its so fucking deep',
#  'asd',
#  'chao lifr',
#  'sabaping',
#  'trihard where the trihex subs at',
#  '@clintstevens cluntbot will be back soon cafsneak was on vacation when it broke',
#  'how is he 23mins ahead',
#  'oh u suck',
#  'do a run',
#  'clintr clintr clintr clintr clintr clintr clintr',
#  'night yo',
#  'clint can you read this out loud',
#  '¯_ツ_¯ inurjeezy inhale the dong',
#  'ur married',
#  'golden sun clintgasm clintgasm clintgasm clintgasm clintgasm clintgasm clintgasm',
#  'play botw and makar has a purpose',
#  'hi clint curly will betray you like judas seemsgood',
#  'kappa 123',
#  'why are you being so quiet',
#  'theres that chat voice again',
#  'holy shit thats hideous',
#  'youre taller than avery bradley',
#  'omfgggg',
#  'clints so smart he skipped highschool and went straight to dropping out of college',
#  'the eff is this they are like the same cheepcheep clintcheep cheepcheep clintcheep cheepcheep clintcheep cheepcheep clintcheep',
#  'yeah he did',
#  '@clintstevens get rid of rem or clintk and ill resub right now',
#  'clintfug this literally replaced makar clintb 🔫',
#  'wow clint',
#  'pogchamp clint stevens stream feelsgoodman',
#  'i used makar every second of my life',
#  'clintfug clintfug clintfug clintfug clintfug clintfug clintfug',
#  '@xenoda what are the new emotes xenoda',
#  '@clintstevens hey clint im the one with the twins jersey that you were hating on',
#  'oh shit youre in temple of time only 30 sec into the run wr inc',
#  'thats basically mst lol',
#  'are you old enough to be drinking that',
#  'kappapride o',
#  'do you fap to your own youtube videos',
#  'sup',
#  '@clintstevens whens barrier skip',
#  'mangoweeb <3',
#  '@bonefassio boner',
#  'sometimes this place reminds me of 4chin',
#  'wasted',
#  'clintclean clintcute clint2 clintl clintrem clintyo died for this',
#  '@clintstevens best of luck on the runs tonight man vohiyo',
#  'last run that means ill have to go back to sleep',
#  'clintclean clintclean clintclean',
#  'codine',
#  'rem',
#  'why cant i cheepcheep ',
#  '@mchamy <3',
#  'hey clint c',
#  'chat told me to make medli clint please lul',
#  'wouldnt you be famous at like a clint stevens convention',
#  'well just smile bud  ',
#  'he said one word among many trihard',
#  'the chaos carry',
#  'bitch boy lul',
#  '@xenoda fuck you clintt',
#  'if he does they have to give him holiday pay @clintstevens',
#  'kys yourself',
#  '💏🖕',
#  'no deceit clintb',
#  'lethal emote',
#  'easter sunday',
#  'bye forever makar tearglove',
#  'i used makar in other botw streams',
#  '@clintstevens you can do it clint your dick is seven inches pogchamp',
#  'raij lul',
#  'how come i cant bitfarm',
#  'thats so funny',
#  'hoe',
#  'play overwatch pogchamp',
#  '@ifknlovecoryinthehouse id say no thats retarded unless its dope and gonna get chicks',
#  'dansgame i need something fresh',
#  'jennifer is probs his cousin wishing him a happy easter',
#  'down with clint',
#  'missing',
#  'all about team fortress 1',
#  'we want makar back clintchoco',
#  'clintfug clints memes',
#  'at work',
#  'what about starforx64 multiplayer',
#  'clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset clintc no clintc reset',
#  'thats the spirit we believe',
#  '@clintstevens i fap to your face 4 times per stream d',
#  'hahah hp',
#  '@curlyfrylol jerk off on a new pizza leave it in office boss steals it boss now is mouth pregnant from your man goo',
#  'hey clint pogchamp ',
#  'clintfug cheepcheep clintfug cheepcheep clintfug cheepcheep clintfug cheepcheep',
#  'clint im gonna tongue punch you in the fart box not in a good way either clintl',
#  'speedrunning that game is hell',
#  '@chuckthegypsy ow',
#  'lmaooo',
#  'i didnt see the shirt could you post it again @ifknlovecoryinthehouse',
#  'vohiyo voltai',
#  '@clintstevens hey clint nice gold clintfug clint2',
#  'poljar xd',
#  'mow 5 ',
#  'whats the its not your fault quote ',
#  'gotta donate again energiez ¯_ツ_¯',
#  'makar had literally zero purpose and the only people who used it were the butthurts cucks who spammed the dont get rid of makar shit lul',
#  'clintchoco clints clintchoking clintj clintrem clinthi clintk clintaww clintred clintred',
#  'how do you pee when your on a run',
#  'yo chuck mod me now',
#  'makes sense',
#  'its like im watching distortion2 reset ds1 clintc',
#  'feelsgoodman youre loved j_daisley i love you <3 feelsgoodman',
#  'never get to see you past 1 hour in game',
#  'can save 40 in ice cavern kappa',
#  'its louder than usual unnoticed that',
#  'that sounds beyond amazing',
#  'mcat',
#  'clint you should make a triforce out of the soundproofing behind you xd',
#  'clint i just wanna play ow with you because youre my favorite person <3',
#  '@303devilfish rekt',
#  '*',
#  'wat would u know about how good a game is you cant even finish oot lul',
#  'free smoke',
#  'did you use your streamer privilege to get that muppet fired',
#  'nice second try',
#  '@clintstevens why bottle before getting hover boots',
#  'rip stream',
#  'cucked feelsbadman',
#  'scammed trihard',
#  'man my favorite part of thanksgiving is when my mom makes the crayonberry sauce',
#  'modding here has always been chill',
#  'hey clunt',
#  'hey at least we dont link pictures of you messing up on pbpace runs which is sort of like what reckfuls chat does when they link him his missed lethal at blizzcon every day lul',
#  'i love ori feelsgoodman',
#  'enerjebic',
#  'dude it is puncay',
#  'where did he go',
#  'clint2 clint2 clint2 clint2 clint2 clint2 clint2',
#  '@clintstevens otc = over the counter',
#  'lulll',
#  'holly shit',
#  'brb',
#  'discord',
#  'its not your faultits not your faultits not your faultits not your fault',
#  'in china it can smoke inside everywhere',
#  'lets crack some good ol penis jokes hahaa',
#  'moonmoon autists minglee',
#  'makars life ends and so does mine clintb 🔫',
#  'id tell you to read a book but i know you cant read so next best thing is audio books @clintstevens',
#  'clintred clintfug',
#  'hope youre having a good nightday',
#  'clint has been told to kill himself multiple times a day for over a year lol',
#  'run a mile lol',
#  'the computer',
#  'clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg clintchoco clintg',
#  'clintfug dont fuck up',
#  'frys jobs are to make sure you dont steal stuff nothing else',
#  '@clintstevens those ppl are toxic cuz they feed off the negativity on camera',
#  'you killed makar for this clintfug',
#  ' feelsbadman',
#  'lmao do it',
#  'he just left',
#  'hey guys what if link is actually kazoo kid',
#  'truely tho',
#  'i finally finished danganronpa 2 yesterday clint',
#  '@clintstevens hows your balls today',
#  'punoko punoko punoko',
#  'hi clint feelsgoodman',
#  'moonmoon scum dansgame',
#  '@permitzi vohiyo <3',
#  'cuck abuse',
#  'i will never use the new emotes that replaced my boy makar',
#  'trap channel in discord i already dont post in there dont tempt me even more dansgame',
#  'clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc',
#  'was that dope',
#  'clintfug where is makar clintfug',
#  'clintclean  cheepcheep',
#  'just turn splits off imo lol',
#  'when do we ever use rem',
#  'cigrip',
#  '@clintstevens i believe in you clint youre getting better everyday',
#  '@bambiku roow <3',
#  'you can dl it on your phone kotor is still good',
#  'clint just do a no reset to break through the beginning even if you wont even get close to a pb just breaking through helps',
#  'shes not bbw but smoking hot still',
#  'clintfug clintw cheepcheep clintcheep cheepcheep clintcheep cheepcheep clintcheep clintfug',
#  'yes pls',
#  'you have so many stupid emotes and you get rid of good ones',
#  'physical stores lul',
#  'secretary',
#  'clintm clintm clintm clintm clintm clintm clintm clintm clintm clintm',
#  'tyler1na tyler1na tyler1na tyler1na',
#  'that was the run',
#  '@elyissial it got broken ive been wondering when itll be fixed as well ',
#  'clintpanic',
#  'ah is not too badd ae',
#  '@clintstevens hey dude',
#  'the day they remove kappa twitch dies',
#  'just do it',
#  's u p e r g u a r d',
#  'circlejerking is human nature 4head',
#  'residentsieeper',
#  'its korean you arrogant **** unsubscribed unfollowed kappa',
#  'ohh alright my b then',
#  'clintc clintc clintc clintc clintc clintc clintc clintc clintc clintc',
#  '@cyrusthevirus001 are @hayleydanger boobs bigger than rems also is she waifu material thank you',
#  'definition of bitch',
#  '@clintstevens congrats on beating the celtics after isaiahs sister died you heartless chicago fan',
#  'unless he lied',
#  'night clinto',
#  'i feel ya man yeah good point',
#  '@hayleydanger ill get you a 711 hotdog',
#  'press 1 if he should quit like a pussy',
#  'splint screamins',
#  'je veux parle francis avec toi ',
#  'forsen sub wutface',
#  '@clintstevens i picture him as your bouncer and being ripped as fuck',
#  'heyguys sleep well',
#  'clinton',
#  'whats your dampy run pb',
#  'yeti garbo',
#  'keep rem or i unsub',
#  'also send me whatever u need clint to see ill dm him it',
#  'clint do youve see 13 reason why',
#  'clintm ',
#  'this is the run i feel it pogchamp',
#  'racist energz racist energz racist energz racist energz racist energz racist energz',
#  'clintgasm clintgasm clintgasm clintgasm clintgasm clintgasm clintgasm clintgasm clintgasm clintgasm',
#  'this channel is now hosting kaceytron',
#  'lul i know that feeling feelsbadman',
#  'the used to be a feelsgoodman blackwake stream feelsbadman',
#  'kappa kappa kappa kappa',
#  'whats the difference between a 1 bomb and 2 bomb hess',
#  'clint pb and ill add you to my top 8 on myspace',
#  'it looks like a ripped off version',
#  '>complaining about wife having a penis',
#  'does that game hold up',
#  'is energz the french guy',
#  'clintstevens body pillow gunlewd',
#  '@clintstevens xenoda nazis your chat enough to cover for you dw',
#  'dont softlock kappa',
#  'potato mic',
#  'badlu',
#  'squishy did nothing wrong',
#  'boogey man wutface',
#  'you killed makar and dampe clintchoco clintchoco clintchoco clintchoco clintchoco clintchoco clintchoco',
#  'well what are you waiting for then',
#  'you are damn sexy baby',
#  'if you arent enjoying it then you should just do something else though',
#  'take otc sleeping pills they knock you out',
#  '@shinycutesylveon t thats cute can you play for ne',
#  'feelsbadman rough day',
#  'wait makars gone',
#  'you killed makar you bully',
#  'nice whechey',
#  'just unscrew it and tie a plastic bag around it when you need to make smoke',
#  'clintchoco clintchoco clintchoco clintchoco clintchoco clintchoco clintchoco clintchoco clintchoco',
#  'how many 5050 chances are in the run',
#  'we all are',
#  'the tilt notlikethis',
#  '@clintstevens calm down clint',
#  'why did clint move',
#  'what the hell is rem anyway',
#  'dans clint2',
#  'fuck me',
#  'pls show us that little shuffle again begwan',
#  'rip it fast',
#  'however many minutes youre behind at the end of the no reset run is how many people you ban from chat',
#  'imglitch',
#  'i dont think anyone has ever said that',
#  'clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep clintc   clintcheep',
#  'call zfg hes crying biblethump',
#  '@jared_jared_jared same m8 ill sign your note if you sign mine',
#  'ive been told that i run like a retard feelsbadman',
#  '@brookenrubbers o',
#  'hell read that',
#  'weebs lol',
#  '@4eign chill',
#  'if you dont put makar back im knocking you down to 3rd babyrage',
#  '@clintstevens what is the meaning behind speedrunning',
#  'clintcheep cheepcheep clintcheep cheepcheep clintcheep cheepcheep clintcheep cheepcheep clintcheep cheepcheep clintcheep scaredycat clintcheep harestare',
#  'i agree omgscoots',
#  'tehepelo koncha punoko tearglove',
#  'its so bad lul',
#  'awww we kid man',
#  'if i saw you in real life i would screech so loud',
#  '@rawfulma0 what did you eat for dinner',
#  'clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug clintfug',
#  'wunce moor',
#  'im a dike bitch one trick on ow clintw',
#  '@xenoda i mean all i did was edit it i didnt redraw it skuzshrug he asked for an edit not an entire redrawing clintc',
#  'yeah this chat has gotten me laid so many times',
#  'wow what a legend',
#  'guys so much time save later',
#  'clintstevens is getting belligerent at this point residentsleeper',
#  '39m 10s ',
#  'xenoda lul',
#  '@noobberry he hasnt even replaced saria so lul',
#  '23 is number 1',
#  'i member',
#  'you look really tired @clintstevens',
#  'httpsclipstwitchtvscrumptiousshortcrabskappawealth',
#  'sumw',
#  'staff sub pogchamp',
#  'pissed',
#  '<3',
#  'cheepcheep cheepcheep cheepcheep cheepcheep cheepcheep cheepcheep cheepcheep cheepcheep cheepcheep',
#  'lul exposed',
#  'shieet trihard',
#  'no way that would fit nicely clintb',
#  'clintfug clintfug clintfug',
#  'you tilt yourself too much man',
#  'are you homesick yet @clintstevens',
#  'red all day baby',
#  'chickens clintc chickens clintc chickens clintc chickens clintc chickens clintc chickens clintc chickens clintc chickens clintc chickens clintc chickens clintc chickens clintc chickens clintc chickens',
#  '@curlyfrylol sorry default response kappa',
#  'k it is way past my bedtime good night chat <3 good luck and goodnight clint clintcute',
#  'minik',
#  '@bambiku hey bambi <3 ',
#  'is he roasting jews again',
#  '@hayleydanger fly in there and take that ginger man boy stick to be your own',
#  '@lpzeldagamer kephriicry feelsbadman',
#  'do you actually not like the lion king',
#  'nice dart bod',
#  'this used to be a deceit stream feelsbadman',
#  'tf is this new emote',
#  'my boiii',
#  '@clintstevens yeah its like sucking ur own dick lul',
#  'stop hating on my nigga clint',
#  'i fap to navi 4 times a stream',
#  'im so confused',
#  'clint racist stevens',
#  'song of yawns lul',
#  '@chuckthegypsy fuck off chuck',
#  'clintcheep 💨💨💨',
#  '@kiraavarosa clinthi',
#  '@jtrost cause he sucks at it',
#  'fight me moobot',
#  'wdf',
#  '@clintstevens i wanna sub to you but youre a fucking weeb with weeb emotes youre a degenerate',
#  'than dont complain that people say mean shit its all that u read you give them the attention',
#  'yep',
#  ' clintfug ',
#  'clintr clintr clintr',
#  'no moon2smug',
#  'rolling around at the speed of sound',
#  '@slippedonanicecube its showing on my screen maybe refresh',
#  'i seriously want to fly to la and give you a hug',
#  'black market lul',
#  'alright forget it lol',
#  'name it kys and then do it',
#  'who the heck is makar',
#  'elena gachigas',
#  'why you look so tired',
#  'cause its like 12 oneast coast',
#  'curly said it energz',
#  'or some shit happened idk lmao',
#  'kappa im the one pogchamp',
#  'residentsleeper clint',
#  'vohiyo noobberry what is clinte',
#  '¯_ツ_¯ enurjeezy praise among the souls of the damned',
#  'yo guys 3',
#  '1h 1m 15s ',
#  'oh my god',
#  '@clintstevens why are your splits so red',
#  '@iambiglucas thats right bruh <3',
#  ...}

# %%
print(len(uniques))
# Out:
# 8491
